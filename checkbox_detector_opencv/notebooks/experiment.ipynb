# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from checkbox_detector import preprocess_image, detect_checkboxes, classify_checkboxes, display_detections

# %% [markdown]
# # Load the document

# %%
path_img_2 = "data/images/d1.jpg"
img2 = cv2.imread(path_img_2)#[340:362, 150:180]
plt.imshow(img2)

# %% [markdown]
# # Convert to grayscale and apply thresholding

# %%
img2 = preprocess_image(path_img_2)#[340:362, 150:180]
plt.imshow(img2)

# %%
checkboxes = detect_checkboxes(img2, True, False)

# %%
filled_checkboxes, unfilled_checkboxes = classify_checkboxes(img2, checkboxes)

# %%
display_detections(img2, filled_checkboxes, unfilled_checkboxes)
